# %%
import os
from pathlib import Path
import shutil
import numpy as np

# %%
raw_label = ['Unlabeled', 'Building', 'Fence', 'Other', 'Pedestrian', 'Pole', 'RoadLine', 'Road',
                   'SideWalk', 'Vegetation', 'Vehicles', 'Wall', 'TrafficSign', 'Sky', 'Ground', 'Bridge'
        , 'RailTrack', 'GuardRail', 'TrafficLight', 'Static', 'Dynamic', 'Water', 'Terrain']

# %%
# 读取原始数据文件名列表
carla_dir = 'data/carla_scene_01_unnorm'
target_dir = 'data/carla_scene_01'
file_list = os.listdir(carla_dir)
test_file_list = os.listdir(target_dir)

# %%
# 定义1类、2类、3类label
valid_label = [1, 4, 5, 7, 8, 9, 10, 11]
trans_label = [0, 1, 2, 3, 4, 5, 6, 7]

# %%
# 创建生成数据文件目录
gen_dir = Path(target_dir)
gen_dir.mkdir(exist_ok=True)
source_folder = os.getcwd() + '/' + carla_dir
target_folder = os.getcwd() + '/' + target_dir

# %%
# 测试
test_file = test_file_list[0]
print(test_file)
end = test_file[-3:]
if end == 'npy':
    raw_data = np.load(target_folder + '/' +test_file)
elif end == 'txt':
    raw_data = np.loadtxt(target_folder + '/' +test_file)
elif end == 'npz':
    raw_data = np.load(target_folder + '/' +test_file)['arr_0']
print(len(raw_data))
# Out:
# 0000000215.npz
# 39887

# %%
for file in file_list:
    # shutil.copyfile(source_folder + file, target_folder + file)
    if file[-3:] == 'npy':
        raw_data = np.load(source_folder + '/' +file)
    elif file[-3:] == 'txt':
        raw_data = np.loadtxt(source_folder + '/' +file)
    # renewdata = [list(raw) for raw in raw_data]
    filename = file.split('.',1)
    renewdata = []
    if os.path.exists(target_folder + '/' + filename[0]+'.npz'):
        continue
    for raw in raw_data:
        if raw[5] in valid_label:
            raw[5] = trans_label[valid_label.index(raw[5])]
            raw = [np.float32(raw[0]), np.float32(raw[1]), np.float32(raw[2]),np.float32(raw[3]),np.float32(raw[4]),np.float32(raw[5])]
            renewdata.append(raw)
    renewdata = np.asarray(renewdata)
    np.savez(target_folder + '/' + filename[0], renewdata)
    # data = np.load(target_folder + file)

    print("%s convert complete" % file)
# Out:
# 0000004400.npy convert complete
# 0000004403.npy convert complete
# 0000004406.npy convert complete
# 0000004409.npy convert complete
# 0000004412.npy convert complete
# 0000004415.npy convert complete
# 0000004418.npy convert complete
# 0000004421.npy convert complete
# 0000004424.npy convert complete
# 0000004427.npy convert complete
# 0000004430.npy convert complete
# 0000004433.npy convert complete
# 0000004436.npy convert complete
# 0000004439.npy convert complete
# 0000004442.npy convert complete
# 0000004445.npy convert complete
# 0000004448.npy convert complete
# 0000004451.npy convert complete
# 0000004454.npy convert complete
# 0000004457.npy convert complete
# 0000004460.npy convert complete
# 0000004463.npy convert complete
# 0000004466.npy convert complete
# 0000004469.npy convert complete
# 0000004472.npy convert complete
# 0000004475.npy convert complete
# 0000004478.npy convert complete
# 0000004481.npy convert complete
# 0000004484.npy convert complete
# 0000004487.npy convert complete
# 0000004490.npy convert complete
# 0000004493.npy convert complete
# 0000004496.npy convert complete
# 0000004499.npy convert complete
# 0000004502.npy convert complete
# 0000004505.npy convert complete
# 0000004508.npy convert complete
# 0000004511.npy convert complete
# 0000004514.npy convert complete
# 0000004517.npy convert complete
